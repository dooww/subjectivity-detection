# %%
import pandas as pd

import numpy as np
from sklearn import preprocessing
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion

# for cross validation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
#from sklearn.model_selection import cross_validation
from sklearn.model_selection import cross_val_predict, cross_val_score

# for various metrics and reporting
from sklearn import metrics 
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# feature selection
from sklearn.feature_selection import SelectFromModel

# xgboost library
from xgboost import XGBClassifier

# plot feature importance
from xgboost import plot_importance, plot_tree

# %%
import matplotlib.pyplot as plt
plt.rc("font", size=14)

# we will use the seaborn for visually appealing plots
import seaborn as sns
sns.set() # set the seaborn stylesheet

# %%
import sys
import types
import pandas as pd
from botocore.client import Config
import boto3

def __iter__(self): return 0

# %%
# data_raw_all = pd.read_txt("example_subjective.txt")
dataset=pd.read_csv("example_subjective.txt",delimiter="\n")
df=pd.read_table('example_subjective.txt',header=None)
print(dataset)
# Out:
#    smart and alert , thirteen conversations about one thing is a small gem .
# 0   color , musical bounce and warm seas lapping o...
# 1   it is not a mass-market entertainment but an u...
# 2   a light-hearted french film about the spiritua...
# 3   my wife is an actress has its moments in looki...
# 4   works both as an engaging drama and an incisiv...
# 5   even a hardened voyeur would require the patie...
# 6   when perry fists a bull at the moore farm , it...
# 7   the characters . . . are paper-thin , and thei...
# 8   the script is a tired one , with few moments o...
# 9   the bland outweighs the nifty , and cletis tou...
# 10  directed by david twohy with the same great ey...
# 11  it's a very tasteful rock and roll movie . you...
# 12  provides the kind of 'laugh therapy' i need fr...
# 13  worth a look by those on both sides of the iss...
# 14  watching the film is like reading a times port...
# 15  despite these annoyances , the capable claybur...
# ...

# %%
import re
def importtxtfile(path):
    list_of_lists = []
    with open(path) as f:
        for line in f:
            z=re.split('; | , |\*|\n',line)
 #         inner_list = [line.strip() for line in re.split(',|.', line)]
            for i in z :
                list_of_lists.append( i)
    return (list_of_lists)

    # ** split character = inspect txt file how columns are separated, normally tab.

    # once you have list of list you can convert it to dataframe using pandas.
    # df = pd.Dataframe(list_of_lists)

# %%
data=importtxtfile("example_subjective.txt")
type(data)
data=cleaningdata(data)

# %%
df1 = pd.DataFrame({'art':data})
print(df1)

def cleaningdata(list):
    for i in list:
        if (len(i)<2) :
            list.remove(i)
    return(list)
# Out:
#                                                   art
# 0                                     smart and alert
# 1   thirteen conversations about one thing is a sm...
# 2                                               color
# 3   musical bounce and warm seas lapping on island...
# 4   it is not a mass-market entertainment but an u...
# 5   a light-hearted french film about the spiritua...
# 6   my wife is an actress has its moments in looki...
# 7                                              though
# 8   it is only mildly amusing when it could have b...
# 9   works both as an engaging drama and an incisiv...
# 10  even a hardened voyeur would require the patie...
# 11  shapeless documentary about the swinging subcu...
# 12          when perry fists a bull at the moore farm
# 13  it's only a matter of time before he gets the ...
# 14                the characters . . . are paper-thin
# 15  and their personalities undergo radical change...
# ...

# %%
df1["subj or obj"]= 0
df1
# Out:
#                                                   art  subj or obj
# 0                                     smart and alert            0
# 1   thirteen conversations about one thing is a sm...            0
# 2                                               color            0
# 3   musical bounce and warm seas lapping on island...            0
# 4   it is not a mass-market entertainment but an u...            0
# 5   a light-hearted french film about the spiritua...            0
# 6   my wife is an actress has its moments in looki...            0
# 7                                              though            0
# 8   it is only mildly amusing when it could have b...            0
# 9   works both as an engaging drama and an incisiv...            0
# 10  even a hardened voyeur would require the patie...            0
# 11  shapeless documentary about the swinging subcu...            0
# 12          when perry fists a bull at the moore farm            0
# ...

# %%
# for i in range len(df):
#     df["subj or obj"][i]=1
df
# Out:
#                                                    art
# 0    the movie begins in the past where a young boy...
# 1
# 2    emerging from the human psyche and showing cha...
# 3                minimalism and russian constructivism
# 4    graffiti removal has secured its place in the ...
# ..                                                 ...
# 99
# 100  straight up : helicopters in action will take ...
# 101
# 102  a lapp woman anni gives a shelter to both of t...
# 103
#
# [104 rows x 1 columns]

# %%
data1=importtxtfile("example_objective.txt")

# %%
data1=cleaningdata(data1)
df = pd.DataFrame({'art':data1})

# %%
df
# Out:
#                                                   art
# 0   the movie begins in the past where a young boy...
# 1   emerging from the human psyche and showing cha...
# 2               minimalism and russian constructivism
# 3   graffiti removal has secured its place in the ...
# 4   spurning her mother's insistence that she get ...
# ..                                                ...
# 69  sees it all as make believe and refuses to bel...
# 70  called " an elegant documentary " by sundance ...
# 71  toyo miyatake : infinite shades of gray is a p...
# 72  straight up : helicopters in action will take ...
# 73  a lapp woman anni gives a shelter to both of t...
#
# [74 rows x 1 columns]

# %%
df["subj or obj"]= 1

# %%
df
# Out:
#                                                   art  subj or obj
# 0   the movie begins in the past where a young boy...            1
# 1   emerging from the human psyche and showing cha...            1
# 2               minimalism and russian constructivism            1
# 3   graffiti removal has secured its place in the ...            1
# 4   spurning her mother's insistence that she get ...            1
# ..                                                ...          ...
# 69  sees it all as make believe and refuses to bel...            1
# 70  called " an elegant documentary " by sundance ...            1
# 71  toyo miyatake : infinite shades of gray is a p...            1
# 72  straight up : helicopters in action will take ...            1
# 73  a lapp woman anni gives a shelter to both of t...            1
#
# [74 rows x 2 columns]

# %%
df_row = pd.concat([df1, df])
#join the dataframe

# %%
df_row
# Out:
#                                                    art  subj or obj
# 0                                      smart and alert          0.0
# 1    thirteen conversations about one thing is a sm...          0.0
# 2                                                               0.0
# 3                                                color          0.0
# 4    musical bounce and warm seas lapping on island...          0.0
# ..                                                 ...          ...
# 99                                                              NaN
# 100  straight up : helicopters in action will take ...          NaN
# 101                                                             NaN
# 102  a lapp woman anni gives a shelter to both of t...          NaN
# 103                                                             NaN
#
# [194 rows x 2 columns]

# %%
df_row.sample(frac=1).reset_index(drop=True)
#mix the dataframe
# Out:
#                                                    art  subj or obj
# 0                                                 1952            1
# 1    works both as an engaging drama and an incisiv...            0
# 2                     he finds out who his father is .            1
# 3                                  extremely well cast            0
# 4    thirteen conversations about one thing is a sm...            0
# ..                                                 ...          ...
# 129  david is a painter with painter's block who ta...            1
# 130        women craved him and men wanted to be him .            1
# 131  toyo miyatake : infinite shades of gray is a p...            1
# 132                                as a young teenager            1
# 133               si el siglo xxi necesita de hï¿½roes            0
#
# [134 rows x 2 columns]

# %%
#split and train the data  frame
from sklearn.datasets import load_boston
boston = load_boston()
df_row.info()
df_row.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 0 to 73
# Data columns (total 2 columns):
# art            134 non-null object
# subj or obj    134 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.1+ KB
#        subj or obj
# count   134.000000
# mean      0.552239
# std       0.499130
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
#separate the  target  from the data
X, y = df_row.iloc[:,:-1],df_row.iloc[:,-1]

#splitting the data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
print(X_train)
print(y_train)

#df_row.to_csv(r'test1.1.csv')
# Out:
#                                                   art
# 2               minimalism and russian constructivism
# 64                      an eleven year old school boy
# 0   the movie begins in the past where a young boy...
# 55                                              nglio
# 41                                               1952
# ..                                                ...
# 17  with few moments of joy rising above the stale...
# 38  gerry's estranged wife margaret is worried for...
# 6                                     rejected by joe
# 66                                            however
# 49                   he finds out who his father is .
#
# [107 rows x 1 columns]
# 2     1
# 64    1
# 0     1
# 55    1
# 41    1
#      ..
# 17    0
# 38    1
# 6     1
# 66    1
# 49    1
# Name: subj or obj, Length: 107, dtype: int64

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,max_depth = 3, n_estimators = 100)

# %%
# # train XGBoost model with default parameters
# my_model = XGBClassifier()
# my_model.fit(X_train, y_train, verbose=False)

# # and save our model
# my_model.save_model("xgboost_baseline.model")

# %%
print ("the hole dataset is here")
# Out:
# the hole dataset is here

# %%
#dataset=pd.read_csv("hello\example_subjective.txt",delimiter="\t")
subjective_train=pd.read_table('hello\subjective_cv_train.txt',header=None)
objective_train=pd.read_table('hello\objective_cv_train.txt',header=None)

# %%
subjective_train=importtxtfile('hello\subjective_cv_train.txt')
objective_train=importtxtfile('hello\objective_cv_train.txt')


#df = pd.DataFrame({'col':data1})
st=pd.DataFrame({'art':cleaningdata(subjective_train)})
ot=pd.DataFrame({'art':cleaningdata(objective_train)})

# %%
st["sub or obj"]=1
ot["sub or obj"]=0

# %%
train = pd.concat([st, ot], ignore_index=True)

train
# Out:
#                                                      art  sub or obj
# 0                                        smart and alert           1
# 1      thirteen conversations about one thing is a sm...           1
# 2                                                  color           1
# 3      musical bounce and warm seas lapping on island...           1
# 4      it is not a mass-market entertainment but an u...           1
# ...                                                  ...         ...
# 19872  the two young women form an unlikely friendshi...           0
# 19873                                                              0
# 19874        they grew up sharing a special relationship           0
# 19875         in which they existed only to each other .           0
# 19876                                                              0
#
# [19877 rows x 2 columns]

# %%
train.sample(frac=1).reset_index(drop=True)
# Out:
#                                                      art  sub or obj
# 0                                      phone councilling           0
# 1                                   looking aristocratic           1
# 2                        to the olympus of the art world           1
# 3      aaliyah rarely dampens her diva persona enough...           1
# 4      this is the amazing story of one man and one w...           0
# ...                                                  ...         ...
# 19872  the twist that ends the movie is the one with ...           1
# 19873  manages to be wholesome and subversive at the ...           1
# 19874  the large-frame imax camera lends itself beaut...           1
# 19875        full of unforgiving irony and quiet realism           1
# 19876  her paranoia seeps insidiously into her newfou...           0
#
# [19877 rows x 2 columns]

# %%
X,y = train.iloc[:,:-1],train.iloc[:,-1]

import category_encoders as ce
# encode all features using ordinal encoding
encoder_x = ce.OrdinalEncoder()
X_encoded = encoder_x.fit_transform(X)

# you'll need to use a different encoder for each dataframe
encoder_y = ce.OrdinalEncoder()
y_encoded = encoder_y.fit_transform(y)

# split encoded dataset
X_train_encoded, X_test_encoded, y_train_encoded, y_test_encoded = train_test_split(X_encoded, y_encoded)

# %%
pip install --upgrade category_encoders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
train.to_csv(r'train1.1.csv')

# %%
encoder_x

from xgboost import XGBClassifier

# train XGBoost model with default parameters
my_model = XGBClassifier(max_depth=3, learning_rate=0.1, verbosity =1, reg_lambda=1)
my_model.fit(X_encoded,y_encoded , verbose=False)





y_pred = my_model.predict(X_test_encoded)

print('accuracy %s' % accuracy_score(y_pred, y_test_encoded))
print(classification_report(y_test_encoded, y_pred))

# and save our model
#my_model.save_model("xgboost_baseline.model")
X_test
# Out:
# C:\Users\hedi\.conda\envs\factory619\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hedi\.conda\envs\factory619\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy 0.9953722334004024
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      2634
#            1       0.99      1.00      1.00      2336
#
#     accuracy                           1.00      4970
#    macro avg       1.00      1.00      1.00      4970
# weighted avg       1.00      1.00      1.00      4970
#                                                   art
# ...

# %%
encoder_x1 = ce.OrdinalEncoder()
X_encoded_test = encoder_x1.fit_transform(X_test)
encoder_y1 = ce.OrdinalEncoder()
y_encoded_test = encoder_y1.fit_transform(y_tereg_lambda= y_pred = my_model.predict(X_encoded_test)
# predictions = [round(value) for value in y_encoded_test]

# %%
y_pred = my_model.predict(X_encoded_test)
y_pred=y_pred.tolist()

#  predictions = [round(value) for value in y_encoded_test]

# %%
# x=0
# #y_test=y_test.tolist()
# # print(type(y_pred) ,type(y_test.tolist()))
# for i in range (len(y_pred)):
#     if (y_pred[i]==y_test[i]):
#         x+=1
# x=x/len(y_pred)
# print(x)
